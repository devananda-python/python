# %%
t=(10,20,30,40,50,60)
print("3rd element:",t[2])
print("3rd  element from last:",t[-3])
# Out:
# 3rd element: 30
# 3rd  element from last: 40

# %%
numbers=input("enter comma_separated numbers:")
my_tuple=tuple(map(int,numbers.split(",")))
print("my_tuple:",my_tuple)
print("average:",sum(my_tuple)/len(my_tuple))
# Out:
# enter comma_separated numbers: 10,20,30,40
# my_tuple: (10, 20, 30, 40)
# average: 25.0
