# %%
C=float(input("enter a temperature in celcius"))
F=(C*9/5)+32
print("temparature in fahrenheit:",F)
# Out:
# enter a temperature in celcius 35
# temparature in fahrenheit: 95.0

# %%
K=float(input("enter distance in kilometer:"))
M=K*0.62137
print("kilometers in miles={:.2f}".format(M))
# Out:
# enter distance in kilometer: 42.5
# kilometers in miles=26.41

# %%
import math
r=int(input("enter the radius of a circle:"))
area=math.pi*r*r
print(f"{area=:.2f}")
# Out:
# enter the radius of a circle: 5
# area=78.54

# %%
n=int(input("enter a number:"))
nn=n*11
nnn=n*111
sum=int(n)+int(nn)+int(nnn)
print(n,"+",nn,"+",nnn,"=",sum)
# Out:
# enter a number: 2
# 2 + 22 + 222 = 246

# %%
a=int(input("enetr first number:"))
b=int(input("enetr second number:"))
c=int(input("enetr third number:"))
biggest=max(a,b,c)
print("biggest number is:",biggest)
# Out:
# enetr first number: 3
# enetr second number: 6
# enetr third number: 9
# biggest number is: 9
