# %%
#program to printout all colors from colorset1 not contained in colorset2.
color_set1={"red","blue","green","yellow"}
color_set2={"blue","yellow","purple","orange"}
color_set3=color_set1-color_set2
print(color_set3)
# Out:
# {'green', 'red'}

# %%
#program to printout all colors from color set1 and color set 2.
set_1={"purple","violet","blue"}
set_2={"yellow","orange","red"}
set_3=set_1|set_2
print(set_3)
# Out:
# {'purple', 'red', 'violet', 'blue', 'yellow', 'orange'}
