# %%
#program to printout all colors from colorset1 not contained in colorset2.
set1=set(input("enter colors in set1:").split(","))
set2=set(input("enter colors in set2:").split(","))
set3=set1-set2
print("the colors in set1 but not in set2:",set3)
# Out:
# enter colors in set1:green,blue,yellow,orange
# enter colors in set2:orange,blue
# the colors in set1 but not in set2: {'yellow', 'green'}

# %%
#program to printout all colors from color set1 and color set 2.
set1=set(input("enter colors in set1:").split(","))
set2=set(input("enter colors in set2:").split(","))
set3=set1|set2
print("the colors in both sets are:",set3)
# Out:
# enter colors in set1:green,blue,yellow
# enter colors in set2:orange,green,purple
# the colors in both sets are: {'purple', 'yellow', 'blue', 'green', 'orange'}
