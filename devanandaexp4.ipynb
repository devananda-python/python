# %%
colors=input("enter colors:")
color_list=colors.split(",")
print("first color:",color_list[0])
print("last color:",color_list[-1])
# Out:
# enter colors: red,yellow,blue
# first color: red
# last color: blue

# %%
filename=input("enter filename:")
extension=filename.split(".")[-1]
print("extension:",extension)
# Out:
# enter filename: devu.py
# extension: py

# %%
numbers=input("enter comma-separeted numbers:")
my_list=list(map(int,numbers.split(",")))
print("list:",my_list)
print("sum:",sum(my_list))
# Out:
# enter comma-separeted numbers: 10,20,30,40
# list: [10, 20, 30, 40]
# sum: 100
